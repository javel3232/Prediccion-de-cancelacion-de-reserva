# %%
train_data_file  = 'datasets/train.csv'
test_input_file  = 'datasets/test.csv'
test_preds_file  = 'predictions/predictions.csv'
model_file       = 'model.pkl'

# %%
import sys
python = sys.executable

# %% [markdown]
# # <font color='00A9FF'>Train a model and save it<font>

# %%
# !python scripts/train.py --model_file $model_file --data_file $train_data_file --overwrite_model
# Out:
# 2023-10-30 16:30:37.264 | INFO     | __main__:<module>:25 - overwriting existing model file model.pkl
# 2023-10-30 16:30:37.264 | INFO     | __main__:<module>:31 - loading train data
# 2023-10-30 16:30:37.269 | INFO     | __main__:<module>:45 - fitting model
# 2023-10-30 16:30:37.300 | INFO     | __main__:<module>:53 - meassuring the accuracy of the model
# Accuracy: 68.00%
# 2023-10-30 16:30:37.301 | INFO     | __main__:<module>:57 - saving model to model.pkl

# %%
# !$python scripts/predict.py --model_file $model_file --input_file $test_input_file  --predictions_file $test_preds_file
# Out:
# 2023-10-30 20:25:02.934 | INFO     | __main__:<module>:26 - loading input data
# 2023-10-30 20:25:02.937 | INFO     | __main__:<module>:30 - loading model
# 2023-10-30 20:25:03.271 | INFO     | __main__:<module>:34 - making predictions
# 2023-10-30 20:25:03.275 | INFO     | __main__:<module>:37 - saving predictions to predictions/predictions.csv

# %%
import pandas as pd

train_data = pd.read_csv(train_data_file)

train_data.head()
# Out:
#    id  gravity    ph  osmo  cond  urea  calc  target
# 0   0    1.013  6.19   443  14.8   124  1.45       0
# 1   1    1.025  5.40   703  23.6   394  4.18       0
# 2   2    1.009  6.13   371  24.5   159  9.04       0
# 3   3    1.021  4.91   442  20.8   398  6.63       1
# 4   4    1.021  5.53   874  17.8   385  2.21       1

# %%
test_data = pd.read_csv(test_input_file)

test_data.head()
# Out:
#     id  gravity    ph  osmo  cond  urea   calc
# 0  414    1.017  5.24   345  11.5   152   1.16
# 1  415    1.020  5.68   874  29.0   385   3.46
# 2  416    1.024  5.36   698  19.5   354  13.00
# 3  417    1.020  5.33   668  25.3   252   3.46
# 4  418    1.011  5.87   567  29.0   457   2.36
